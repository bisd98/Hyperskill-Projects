# %% [markdown]
# <a href="https://colab.research.google.com/github/bisd98/PycharmProjects/blob/master/HR_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
upladed = files.upload()
# Out:
#      <input type="file" id="files-999d8ff5-bc3f-4431-9145-257fb6eabcd5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-999d8ff5-bc3f-4431-9145-257fb6eabcd5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving B_office_data.xml to B_office_data.xml
# Saving hr_data.xml to hr_data.xml
# Saving A_office_data.xml to A_office_data.xml

# %%
import pandas as pd

# %%
A_office_data = pd.read_xml('A_office_data.xml')
B_office_data = pd.read_xml('B_office_data.xml')
HR_data = pd.read_xml('hr_data.xml')

# %%
A_office_data.info()
print()
B_office_data.info()
print()
HR_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3019 entries, 0 to 3018
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   number_project         3019 non-null   int64
#  1   average_monthly_hours  3019 non-null   int64
#  2   time_spend_company     3019 non-null   int64
#  3   Work_accident          3019 non-null   int64
#  4   promotion_last_5years  3019 non-null   int64
#  5   Department             3019 non-null   object
#  6   salary                 3019 non-null   object
#  7   employee_office_id     3019 non-null   int64
# dtypes: int64(6), object(2)
# memory usage: 188.8+ KB
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5981 entries, 0 to 5980
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   number_project         5981 non-null   int64
# ...

# %%
HR_data.set_index('employee_id', inplace=True)

# %%
A_office_data['employee_office_id']
for x in A_office_data['employee_office_id']:
  A_office_data['employee_office_id'].replace({x: 'A' + str(x)}, inplace=True)

# %%
B_office_data['employee_office_id']
for x in B_office_data['employee_office_id']:
  B_office_data['employee_office_id'].replace({x: 'B' + str(x)}, inplace=True)

# %%
A_office_data['employee_office_id']
# Out:
# 0          A2
# 1          A4
# 2          A6
# 3          A7
# 4          A9
#         ...
# 3014    A4991
# 3015    A4992
# 3016    A4995
# 3017    A4998
# 3018    A4999
# Name: employee_office_id, Length: 3019, dtype: object

# %%
A_office_data.set_index('employee_office_id', inplace=True)
B_office_data.set_index('employee_office_id', inplace=True)

# %%
print((A_office_data.index).to_list())
print((B_office_data.index).to_list())
print((HR_data.index).to_list())

# %%
A_office_data
# Out:
#                     number_project  average_monthly_hours  time_spend_company  \
# employee_office_id
# A2                               5                    262                   6
# A4                               5                    223                   5
# A6                               2                    153                   3
# A7                               6                    247                   4
# A9                               5                    224                   5
# ...                            ...                    ...                 ...
# A4991                            3                    151                   3
# A4992                            3                     98                   3
# A4995                            5                    250                   3
# A4998                            5                    189                   5
# A4999                            5                    138                   3
#
# ...

# %%
Unified_data = pd.concat([A_office_data, B_office_data])

# %%
Unified_data
# Out:
#                     number_project  average_monthly_hours  time_spend_company  \
# employee_office_id
# A2                               5                    262                   6
# A4                               5                    223                   5
# A6                               2                    153                   3
# A7                               6                    247                   4
# A9                               5                    224                   5
# ...                            ...                    ...                 ...
# B9990                            2                    159                   3
# B9991                            5                    228                   5
# B9993                            2                    155                   3
# B9998                            6                    280                   4
# B9999                            2                    158                   3
#
# ...

# %%
HR_data
# Out:
#              satisfaction_level  last_evaluation  left
# employee_id
# A1                         0.38             0.53     1
# A3                         0.11             0.88     1
# A4                         0.72             0.87     1
# A5                         0.37             0.52     1
# A7                         0.10             0.77     1
# ...                         ...              ...   ...
# B9995                      0.40             0.57     1
# B9996                      0.37             0.48     1
# B9997                      0.37             0.53     1
# B9998                      0.11             0.96     1
# B9999                      0.37             0.52     1
#
# [10000 rows x 3 columns]

# %%
Unified_data = Unified_data.merge(HR_data, how='inner', left_index=True, right_index=True, indicator=True)

# %%
Unified_data
# Out:
#        number_project  average_monthly_hours  time_spend_company  \
# A4                  5                    223                   5
# A7                  6                    247                   4
# A10                 2                    142                   3
# A11                 2                    135                   3
# A14                 2                    148                   3
# ...               ...                    ...                 ...
# B9985               2                    148                   3
# B9990               2                    159                   3
# B9991               5                    228                   5
# B9998               6                    280                   4
# B9999               2                    158                   3
#
#        Work_accident  promotion_last_5years Department  salary  \
# A4                 0                      0      sales     low
# ...

# %%
Unified_data.sort_index()
# Out:
#        number_project  average_monthly_hours  time_spend_company  \
# A10                 2                    142                   3
# A100                5                    221                   6
# A1002               6                    267                   4
# A1003               2                    141                   3
# A1006               4                    260                   3
# ...               ...                    ...                 ...
# B9985               2                    148                   3
# B9990               2                    159                   3
# B9991               5                    228                   5
# B9998               6                    280                   4
# B9999               2                    158                   3
#
#        Work_accident  promotion_last_5years Department  salary  \
# A10                0                      0      sales     low
# ...

# %% [markdown]
# **First piece of my final DataFrame** Number project

# %% [markdown]
# First function which I use to count values bigger than 5 in Series 'number_project'

# %%
def count_bigger_5(series):
  return series.where(series > 5).count()

# %% [markdown]
# A piece of code with which I test if my function works properly:

# %%
Unified_data['number_project'].agg(count_bigger_5)
# Out:
# 546

# %%
nr_project = {'number_project': ['median', count_bigger_5]}

# %%
first_pc = Unified_data.groupby('left').agg(nr_project)

# %% [markdown]
# **Second piece of my DataFrame** Time spend company

# %%
time_spend = {'time_spend_company': ['mean', 'median']}

# %%
second_pc = Unified_data.groupby('left').agg(time_spend)

# %% [markdown]
# **Third piece of my Data Frame** Work accident

# %%
work_acc = {'Work_accident': ['mean']}

# %%
third_pc = Unified_data.groupby('left').agg(work_acc)

# %% [markdown]
# **Last piece of my final DataFrame** Last evaluation

# %%
agg_func_count = {'embark_town': ['count', 'nunique', 'size']}
df.groupby(['deck']).agg(agg_func_count)

# %%
last_eval = {'last_evaluation': ['mean', 'std']}

# %%
fourth_pc = Unified_data.groupby('left').agg(last_eval)

# %%
final_df = pd.concat([first_pc, second_pc, third_pc, fourth_pc], axis=1)

# %%
final_df = round(final_df, 2)

# %%
final_df
# Out:
#      number_project                time_spend_company        Work_accident  \
#              median count_bigger_5               mean median          mean
# left
# 0               4.0            207               3.40    3.0          0.18
# 1               4.0            339               3.91    4.0          0.04
#
#      last_evaluation
#                 mean   std
# left
# 0               0.72  0.16
# 1               0.72  0.20

# %%
print(final_df.to_dict())
# Out:
# {('number_project', 'median'): {0: 4.0, 1: 4.0}, ('number_project', 'count_bigger_5'): {0: 207, 1: 339}, ('time_spend_company', 'mean'): {0: 3.4, 1: 3.91}, ('time_spend_company', 'median'): {0: 3.0, 1: 4.0}, ('Work_accident', 'mean'): {0: 0.18, 1: 0.04}, ('last_evaluation', 'mean'): {0: 0.72, 1: 0.72}, ('last_evaluation', 'std'): {0: 0.16, 1: 0.2}}

# %%
Unified_data
# Out:
#        number_project  average_monthly_hours  time_spend_company  \
# A4                  5                    223                   5
# A7                  6                    247                   4
# A10                 2                    142                   3
# A11                 2                    135                   3
# A14                 2                    148                   3
# ...               ...                    ...                 ...
# B9985               2                    148                   3
# B9990               2                    159                   3
# B9991               5                    228                   5
# B9998               6                    280                   4
# B9999               2                    158                   3
#
#        Work_accident  promotion_last_5years Department  salary  \
# A4                 0                      0      sales     low
# ...

# %%
first_table = pd.pivot_table(Unified_data, index='Department', columns=['left', 'salary'], values='average_monthly_hours').round(2)

# %%
first_table

# %%
first_to_dict = first_table.loc[(first_table[0].high < first_table[0].medium) & (first_table[1].low < first_table[1].high)]

# %%
second_table= pd.pivot_table(Unified_data, index='time_spend_company', columns='promotion_last_5years', values=['last_evaluation', 'satisfaction_level'], aggfunc=['min', 'max', 'mean'])

# %%
second_table
# Out:
#                                   min                                 \
#                       last_evaluation       satisfaction_level
# promotion_last_5years               0     1                  0     1
# time_spend_company
# 2                                0.37  0.52               0.09  0.29
# 3                                0.36  0.41               0.11  0.24
# 4                                0.36  0.42               0.09  0.15
# 5                                0.38  0.37               0.09  0.23
# 6                                0.37  0.38               0.12  0.48
# 7                                0.38  0.55               0.15  0.16
# 8                                0.40  0.40               0.15  0.50
# 10                               0.37  0.48               0.14  0.22
#
#                                   max                                 \
#                       last_evaluation       satisfaction_level
# ...

# %%
second_to_dict = second_table.loc[second_table['mean']['last_evaluation'][0] > second_table['mean']['last_evaluation'][1]]

# %%
print(first_to_dict.to_dict())
# Out:
# {(0, 'high'): {'sales': 195.45}, (0, 'low'): {'sales': 197.39}, (0, 'medium'): {'sales': 198.97}, (1, 'high'): {'sales': 231.5}, (1, 'low'): {'sales': 204.05}, (1, 'medium'): {'sales': 210.07}}

# %%
print(second_to_dict.to_dict())
# Out:
# {('min', 'last_evaluation', 0): {3: 0.36, 7: 0.38, 8: 0.4}, ('min', 'last_evaluation', 1): {3: 0.41, 7: 0.55, 8: 0.4}, ('min', 'satisfaction_level', 0): {3: 0.11, 7: 0.15, 8: 0.15}, ('min', 'satisfaction_level', 1): {3: 0.24, 7: 0.16, 8: 0.5}, ('max', 'last_evaluation', 0): {3: 1.0, 7: 0.95, 8: 0.99}, ('max', 'last_evaluation', 1): {3: 0.99, 7: 0.93, 8: 1.0}, ('max', 'satisfaction_level', 0): {3: 1.0, 7: 1.0, 8: 0.97}, ('max', 'satisfaction_level', 1): {3: 1.0, 7: 0.93, 8: 0.95}, ('mean', 'last_evaluation', 0): {3: 0.6703552684699233, 7: 0.6726086956521738, 8: 0.71625}, ('mean', 'last_evaluation', 1): {3: 0.7167999999999999, 7: 0.7142857142857143, 8: 0.7466666666666666}, ('mean', 'satisfaction_level', 0): {3: 0.6285870004037142, 7: 0.7007246376811594, 8: 0.65421875}, ('mean', 'satisfaction_level', 1): {3: 0.7092, 7: 0.5842857142857143, 8: 0.5950000000000001}}

# %%
second_to_dict
# Out:
#                                   min                                 \
#                       last_evaluation       satisfaction_level
# promotion_last_5years               0     1                  0     1
# time_spend_company
# 2                                0.37  0.52               0.09  0.29
# 4                                0.36  0.42               0.09  0.15
# 5                                0.38  0.37               0.09  0.23
# 6                                0.37  0.38               0.12  0.48
# 10                               0.37  0.48               0.14  0.22
#
#                                   max                                 \
#                       last_evaluation       satisfaction_level
# promotion_last_5years               0     1                  0     1
# time_spend_company
# 2                                 1.0  0.99               1.00  0.94
# 4                                 1.0  0.90               1.00  0.94
# ...
